# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathkumar1508/LGMVIP_DS/blob/main/IMAGE_TO_PENCIL_SKETCH_USING_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import cv2 as cv
from google.colab.patches import cv2_imshow #image display
from skimage import io
from PIL import Image
import matplotlib.pyplot as plt
import urllib.request

# %%
image= io.imread("R.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x670 at 0x7F11EEC86880>

# %%
grey_filter=cv.cvtColor(image,cv.COLOR_BGR2GRAY)
cv2_imshow(grey_filter)
# Out:
# <PIL.Image.Image image mode=L size=500x670 at 0x7F11DAB1A9D0>

# %%
invert=cv.bitwise_not(grey_filter)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=500x670 at 0x7F11EEC865E0>

# %%
blur=cv.GaussianBlur(invert,(21,21),0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=500x670 at 0x7F11F2F64940>

# %%
invertedblur=cv.bitwise_not(blur)
cv2_imshow(invertedblur)
# Out:
# <PIL.Image.Image image mode=L size=500x670 at 0x7F11F1EFEFD0>

# %%
sketch_filter=cv.divide(grey_filter,invertedblur,scale=255.0)
cv2_imshow(sketch_filter)
cv.imwrite("sketch.jpg",sketch_filter)
# Out:
# <PIL.Image.Image image mode=L size=500x670 at 0x7F11F1EFE850>
# True
